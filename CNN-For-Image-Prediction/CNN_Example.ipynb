# %%
#!pip install keras
#tf.__version__
# Out:
# '2.16.1'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#DATA PREPROCESSING
#PREPROCESSING the Train_Set
train_datagen = ImageDataGenerator(
                rescale = 1./255,
                shear_range = 0.2,
                zoom_range = 0.2,
                horizontal_flip = True)

training_set = train_datagen.flow_from_directory(
        'dataset/training_set',
        target_size= (64, 64),
        batch_size= 32,
        class_mode= 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
#PREPROCESSING the Test_Set

test_datagen =  ImageDataGenerator(rescale = 1./255)
test_set= test_datagen.flow_from_directory(
        'dataset/test_set',
        target_size= (64, 64),
        batch_size= 32,
        class_mode= 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
#Creating A CNN 

cnn= tf.keras.models.Sequential()

# %%
#Step One - Convolution

cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3, activation='relu', input_shape=[64,64,3]))
# Out:
# D:\Anacoda\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
#Step Two - Pooling 

cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
#Creating A Second Layer

cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
#Step Three - Flattening

cnn.add(tf.keras.layers.Flatten())

# %%
#Step Four - Full Connection

cnn.add(tf.keras.layers.Dense(units= 128, activation='relu'))

# %%
#Step Four - Complete The Model

cnn.add(tf.keras.layers.Dense(units= 1, activation='sigmoid'))

# %%
# Step Five - Compiling and TRAINING The Model

#Compiling
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics =['accuracy'])

#Training
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# D:\Anacoda\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.5513 - loss: 0.6888 - val_accuracy: 0.6840 - val_loss: 0.6083
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 179ms/step - accuracy: 0.6791 - loss: 0.6010 - val_accuracy: 0.7235 - val_loss: 0.5511
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 180ms/step - accuracy: 0.7349 - loss: 0.5351 - val_accuracy: 0.7360 - val_loss: 0.5309
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 180ms/step - accuracy: 0.7482 - loss: 0.5097 - val_accuracy: 0.7600 - val_loss: 0.4947
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 179ms/step - accuracy: 0.7650 - loss: 0.4895 - val_accuracy: 0.7695 - val_loss: 0.4870
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.7619 - loss: 0.4879 - val_accuracy: 0.7675 - val_loss: 0.5005
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 181ms/step - accuracy: 0.7831 - loss: 0.4535 - val_accuracy: 0.7760 - val_loss: 0.4812
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 182ms/step - accuracy: 0.7781 - loss: 0.4513 - val_accuracy: 0.7885 - val_loss: 0.4670
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.7963 - loss: 0.4269 - val_accuracy: 0.7575 - val_loss: 0.5080
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8152 - loss: 0.3979 - val_accuracy: 0.7965 - val_loss: 0.4626
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 175ms/step - accuracy: 0.8147 - loss: 0.4004 - val_accuracy: 0.7980 - val_loss: 0.4581
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8112 - loss: 0.4119 - val_accuracy: 0.7900 - val_loss: 0.4871
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8270 - loss: 0.3732 - val_accuracy: 0.8060 - val_loss: 0.4479
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 172ms/step - accuracy: 0.8348 - loss: 0.3615 - val_accuracy: 0.7865 - val_loss: 0.4622
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.8441 - loss: 0.3522 - val_accuracy: 0.8030 - val_loss: 0.4622
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.8510 - loss: 0.3366 - val_accuracy: 0.8120 - val_loss: 0.4415
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 174ms/step - accuracy: 0.8554 - loss: 0.3239 - val_accuracy: 0.7830 - val_loss: 0.4691
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8547 - loss: 0.3297 - val_accuracy: 0.8115 - val_loss: 0.4686
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8707 - loss: 0.2957 - val_accuracy: 0.8075 - val_loss: 0.4746
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 174ms/step - accuracy: 0.8788 - loss: 0.2848 - val_accuracy: 0.8155 - val_loss: 0.4487
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.8873 - loss: 0.2683 - val_accuracy: 0.8175 - val_loss: 0.4755
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 173ms/step - accuracy: 0.8980 - loss: 0.2525 - val_accuracy: 0.8045 - val_loss: 0.4875
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 174ms/step - accuracy: 0.8992 - loss: 0.2477 - val_accuracy: 0.7565 - val_loss: 0.6114
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 174ms/step - accuracy: 0.9031 - loss: 0.2482 - val_accuracy: 0.8200 - val_loss: 0.4869
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - accuracy: 0.9058 - loss: 0.2311 - val_accuracy: 0.8080 - val_loss: 0.5326

# %%
#Step Six - Making A Single Prediction
import numpy as np
from keras.preprocessing import image

test_image = image.load_img('single_prediction/cat_or_dog_2.jpg',target_size= (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'Dog'
else:
    prediction = 'Cat'
    
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Cat
